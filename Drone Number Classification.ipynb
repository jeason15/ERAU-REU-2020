# %%
import pandas as pd
import scipy
from scipy import io

from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import scipy
from scipy import io
import numpy as np
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# 0
drone0a = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/cv0a.mat')
features = drone0a['resultMatrix0']
df0a = pd.DataFrame(features)
x0 = pd.DataFrame(features)

drone0b = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/cv0b.mat')
features = drone0b['resultMatrix']
df0b = pd.DataFrame(features)

drone0c = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/cv0c.mat')
features = drone0c['resultMatrix']
df0c = pd.DataFrame(features)

drone0d = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/cv0d.mat')
features = drone0d['resultMatrix']
df0d = pd.DataFrame(features)

drone0e = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/cv0e.mat')
features = drone0e['resultMatrix']
df0e = pd.DataFrame(features)

drone0f = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/cv0f.mat')
features = drone0f['resultMatrix']
df0f = pd.DataFrame(features)

# 1
drone1a = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_12_3M.mat')
features = drone1a['resultMatrix0']
df1a = pd.DataFrame(features)

drone1b = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_12_5M.mat')
features = drone1b['resultMatrix0']
df1b = pd.DataFrame(features)

drone1c = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_12_7M.mat')
features = drone1c['resultMatrix0']
df1c = pd.DataFrame(features)

drone1d = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_15_3M.mat')
features = drone1d['resultMatrix0']
df1d = pd.DataFrame(features)

drone1e = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_15_5M.mat')
features = drone1e['resultMatrix0']
df1e = pd.DataFrame(features)

drone1f = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_15_7M.mat')
features = drone1f['resultMatrix0']
df1f = pd.DataFrame(features)

drone1g = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_AT10_3M.mat')
features = drone1g['resultMatrix0']
df1g = pd.DataFrame(features)

drone1h = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_AT10_5M.mat')
features = drone1h['resultMatrix0']
df1h = pd.DataFrame(features)

drone1i = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_AT10_7M.mat')
features = drone1i['resultMatrix0']
df1i = pd.DataFrame(features)

drone1j = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_fpv1_3M.mat')
features = drone1j['resultMatrix0']
df1j = pd.DataFrame(features)

drone1k = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_fpv1_5M.mat')
features = drone1k['resultMatrix0']
df1k = pd.DataFrame(features)

drone1l = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C1_fpv1_7M.mat')
features = drone1l['resultMatrix0']
df1l = pd.DataFrame(features)

# 2
drone2a = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_12_15_3M.mat')
features = drone2a['resultMatrix0']
df2a = pd.DataFrame(features)

drone2b = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_12_15_5M.mat')
features = drone2b['resultMatrix0']
df2b = pd.DataFrame(features)

drone2c = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_12_15_7M.mat')
features = drone2c['resultMatrix0']
df2c = pd.DataFrame(features)

drone2d = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_fpv1_at10_3M.mat')
features = drone2d['resultMatrix0']
df2d = pd.DataFrame(features)

drone2e = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_fpv1_at10_5M.mat')
features = drone2e['resultMatrix0']
df2e = pd.DataFrame(features)

drone2f = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_fpv1_at10_7M.mat')
features = drone2f['resultMatrix0']
df2f = pd.DataFrame(features)

drone2g = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_12_fpv1_3M.mat')
features = drone2g['resultMatrix0']
df2g = pd.DataFrame(features)

drone2h = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_12_fpv1_5M.mat')
features = drone2h['resultMatrix0']
df2h = pd.DataFrame(features)

drone2i = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_12_fpv1_7M.mat')
features = drone2i['resultMatrix0']
df2i = pd.DataFrame(features)


drone2j = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_at10_12_5M.mat')
features = drone2j['resultMatrix0']
df2j = pd.DataFrame(features)

drone2k = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C2_at10_12_7M.mat')
features = drone2k['resultMatrix0']
df2k = pd.DataFrame(features)

# 3
drone3a = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C3_12_at10_15_3M.mat')
features = drone3a['resultMatrix0']
df3a= pd.DataFrame(features)

drone3b = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C3_12_at10_15_5M.mat')
features = drone3b['resultMatrix0']
df3b = pd.DataFrame(features)

drone3c = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C3_12_at10_15_7M.mat')
features = drone3c['resultMatrix0']
df3c = pd.DataFrame(features)

drone3d = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C3_12_at10_fpv1_3M.mat')
features = drone3d['resultMatrix0']
df3d = pd.DataFrame(features)

drone3e = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C3_12_at10_fpv1_5M.mat')
features = drone3e['resultMatrix0']
df3e = pd.DataFrame(features)

drone3f = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C3_12_at10_fpv1_7M.mat')
features = drone3f['resultMatrix0']
df3f = pd.DataFrame(features)

# 4
drone4a = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C4_3M.mat')
features = drone4a['resultMatrix0']
df4a = pd.DataFrame(features)

drone4b = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C4_5M.mat')
features = drone4b['resultMatrix0']
df4b = pd.DataFrame(features)

drone4c = scipy.io.loadmat('drive/My Drive/SongLab/data/data_sampling/C4_7M.mat')
features = drone4c['resultMatrix0']
df4c = pd.DataFrame(features)

# %%
#training data
#x0
x0a_b = np.vstack((df0a,df0b))
x0a_c = np.vstack((x0a_b,df0c))
x0a_f = np.vstack((x0a_c,df0d))
x0a_e = np.vstack((x0a_f,df0e))
x0 = np.vstack((x0a_e,df0f))

#x1
x1a_b = np.vstack((df1a,df1b))
x1a_c = np.vstack((x1a_b,df1c))
x1a_d = np.vstack((x1a_c,df1d))
x1a_e = np.vstack((x1a_d,df1e))
x1a_f = np.vstack((x1a_e,df1f))
x1a_g = np.vstack((x1a_f,df1g))
x1a_h = np.vstack((x1a_g,df1h))
x1a_i = np.vstack((x1a_h,df1i))
x1a_j = np.vstack((x1a_i,df1j))
x1a_k = np.vstack((x1a_j,df1k))
x1 = np.vstack((x1a_k,df1l))

#x2
x2a_b = np.vstack((df2a,df2b))
x2a_c = np.vstack((x2a_b,df2c))
x2a_d = np.vstack((x2a_c,df2d))
x2a_e = np.vstack((x2a_d,df2e))
x2a_f = np.vstack((x2a_e,df2f))
x2a_g = np.vstack((x2a_f,df2g))
x2a_h = np.vstack((x2a_g,df2h))
x2a_i = np.vstack((x2a_h,df2i))
x2a_j = np.vstack((x2a_i,df2j))
x2 = np.vstack((x2a_j,df2k))

#x3
x3a_b = np.vstack((df3a,df3b))
x3a_c = np.vstack((x3a_b,df3c))
x3a_d = np.vstack((x3a_c,df3d))
x3a_e = np.vstack((x3a_d,df3e))
x3 = np.vstack((x3a_e,df3f))

#x4
x4a_b = np.vstack((df4a,df4b))
x4 = np.vstack((x4a_b,df4c))

# %%
x4.shape
# Out:
# (3000, 1024)

# %%
y0 = 0 * np.ones((x0.shape[0],1))
y1 = 1 * np.ones((x1.shape[0],1))
y2 = 2 * np.ones((x2.shape[0],1))
y3 = 3 * np.ones((x3.shape[0],1))
y4 = 4 * np.ones((x4.shape[0],1))

y01 =  np.vstack((y0,y1))
y012 =  np.vstack((y01,y2))
y0123 =  np.vstack((y012,y3))
y_labelonly =  np.vstack((y0123,y4)) 

#mix x
x01 = np.vstack((x0,x1))
x012 = np.vstack((x01,x2))
x0123 = np.vstack((x012,x3))
x01234 = np.vstack((x0123,x4))

data_label_mix = np.hstack((x01234,y_labelonly))

# %%
data_label_mix.shape
# Out:
# (38000, 1025)

# %%
np.random.shuffle(data_label_mix)

x = data_label_mix[:,0:-1]
y = data_label_mix[:,-1]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data_label_mix, y, test_size = 0.3)
#x_train = x_train[:,0:-1]

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
#ss = MinMaxScaler()
ss = StandardScaler()
x_train = ss.fit_transform(x_train)
x_test = ss.fit_transform(x_test)

from sklearn.decomposition import PCA
pca = PCA(n_components=0.92)
pca.fit(x_train)
x_train = pca.transform(x_train)  
x_test = pca.transform(x_test)

# %%
from sklearn import neighbors
knn = neighbors.KNeighborsClassifier(n_neighbors=7)
knn.fit(x_train, y_train)
test = knn.predict(x_test)
knn.score(x_test, y_test)
# Out:
# 0.9894736842105263

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(solver='adam', alpha=0.4, hidden_layer_sizes=(30,21,15,9,6),max_iter=800)
clf.fit(x_train, y_train)
test = clf.predict(x_test)
clf.score(x_test, y_test)
# Out:
# 0.9999122807017544

# %%
from sklearn.svm import SVC
svm = SVC(gamma = 'auto')
svm.fit(x_train, y_train)
test = svm.predict(x_test)
svm.score(x_test, y_test)
# Out:
# 0.9851754385964913

# %%
import sklearn
from sklearn.tree import DecisionTreeClassifier
nb =sklearn.tree.DecisionTreeClassifier(criterion='entropy',min_samples_split=5)
nb.fit(x_train, y_train)

test = nb.predict(x_test)
nb.score(x_test, y_test)
# Out:
# 0.9338596491228071

# %%
correct0 = 0
correct1 = 0
correct2 = 0
correct3 = 0
correct4 = 0
for i in range(len(test)):
  if test[i] == y_test[i]:
    if test[i] == 0:
      correct0 += 1
    elif test[i] == 1:
      correct1 += 1
    elif test[i] == 2:
      correct2 += 1
    elif test[i] == 3:
      correct3 += 1
    elif test[i] == 4:
      correct4 += 1

y_test0 = 0
y_test1 = 0
y_test2 = 0
y_test3 = 0
y_test4 = 0
for i in range(len(y_test)):
  if y_test[i] == 0:
    y_test0 += 1
  elif y_test[i] == 1:
    y_test1 += 1
  elif y_test[i] == 2:
    y_test2 += 1
  elif y_test[i] == 3:
    y_test3 += 1
  elif y_test[i] == 4:
    y_test4 += 1

print("accuracy of 0:", correct0/y_test0)
print("accuracy of 1:", correct1/y_test1)
print("accuracy of 2:", correct2/y_test2)
print("accuracy of 3:", correct3/y_test3)
print("accuracy of 4:", correct4/y_test4)
# Out:
# accuracy of 0: 0.965840220385675
# accuracy of 1: 0.936818563041655
# accuracy of 2: 0.9328879441238992
# accuracy of 3: 0.9074792243767313
# accuracy of 4: 0.9142857142857143

# %%
y_train0 = 0
y_train1 = 0
y_train2 = 0
y_train3 = 0
y_train4 = 0
for i in range(len(y_train)):
  if y_train[i] == 0:
    y_train0 += 1
  elif y_train[i] == 1:
    y_train1 += 1
  elif y_train[i] == 2:
    y_train2 += 1
  elif y_train[i] == 3:
    y_train3 += 1
  elif y_train[i] == 4:
    y_train4 += 1


print("num of 0:", y_train0)
print("num of 1:", y_train1)
print("num of 2:", y_train2)
print("num of 3:", y_train3)
print("num of 4:", y_train4)

print("num of 0:", y_test0)
print("num of 1:", y_test1)
print("num of 2:", y_test2)
print("num of 3:", y_test3)
print("num of 4:", y_test4)
# Out:
# num of 0: 4185
# num of 1: 8423
# num of 2: 7707
# num of 3: 4195
# num of 4: 2090
